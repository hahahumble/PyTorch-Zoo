# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms

import os
import requests
from pathlib import Path

# %%
print(Path.cwd())
# Out:
# /root/jupyter_projects/PyTorch-Zoo/Data Augmentation

# %%
# Change this for your own directory.
ROOT_DIR = Path("/root/jupyter_projects")  # Your working directory.
DATASET_DIR = ROOT_DIR / "Data"  # Folder to store dataset.

DATA_DIR = DATASET_DIR / "Caltech_Birds2011"

DATA_DIR.mkdir(parents=True, exist_ok=True)  # Create directory if it do not exist.

image_dir = DATA_DIR

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Define pytorch device.

# %%
print(image_dir)
# Out:
# /root/jupyter_projects/Data/Caltech_Birds2011

# %%
# URL = "https://bucket-oranges-1310562101.cos.ap-guangzhou.myqcloud.com/CUB_200_2011.tgz"
URL = "https://bucket-oranges-1310562101.cos.ap-guangzhou.myqcloud.com/CUB_200_2011.tgz"
file_name = "CUB_200_2011.tgz"
file_path = image_dir / file_name  # Download file path.

# %%
print(file_path)
# Out:
# /root/jupyter_projects/Data/Caltech_Birds2011/Flowers102.tgz

# %%
r = requests.get(URL, allow_redirects=True)
open(file_path, 'wb').write(r.content)

print('Dataset downloaded successfully!')
# Out:
# Dataset downloaded successfully!

# %%
print(len(next(os.walk(image_dir))[1]))
# Out:
# 103

# %%
print(next(os.walk(image_dir))[1])
# Out:
# ['Faces_easy', 'crocodile', 'pyramid', 'stegosaurus', 'bonsai', 'car_side', 'platypus', 'butterfly', 'dalmatian', 'gerenuk', 'Motorbikes', 'gramophone', 'helicopter', 'octopus', 'electric_guitar', 'anchor', 'kangaroo', 'ferry', 'wheelchair', 'pagoda', 'cougar_body', 'buddha', 'rhino', 'BACKGROUND_Google', 'nautilus', 'chandelier', 'menorah', 'lobster', 'elephant', 'grand_piano', 'sea_horse', 'ewer', 'tick', 'panda', 'yin_yang', 'camera', 'cup', 'cougar_face', 'emu', 'airplanes', 'mayfly', 'starfish', 'laptop', 'metronome', 'flamingo', 'crayfish', 'scorpion', 'dragonfly', 'accordion', 'crocodile_head', 'snoopy', 'joshua_tree', 'trilobite', 'soccer_ball', 'sunflower', 'saxophone', 'wrench', 'dollar_bill', 'okapi', 'pizza', 'Faces', 'mandolin', 'headphone', 'water_lilly', 'flamingo_head', 'ibis', 'schooner', 'umbrella', 'euphonium', 'chair', 'cellphone', 'windsor_chair', 'minaret', 'crab', 'inline_skate', 'wild_cat', 'garfield', 'lamp', 'strawberry', 'ceiling_fan', 'dolphin', 'scissors'
# ...
