# %% [markdown]
# ### Built-in Dataset in PyTorch

# %% [markdown]
# Last update by Xi in 2022/3/30.

# %%
import torch
import torchvision
from torchvision import datasets

# %%
# !pwd
# Out:
# /root/jupyter_projects/PyTorch-Zoo/Load Data in PyTorch

# %%
DATASET_DIR = "/root/jupyter_projects/Data/cifar10-builtin"

# %%
train_data = datasets.CIFAR10(
    root=DATASET_DIR,  # Directory to store data.
    train=True,  # true for training set.
    download=True,  # Download dataset from internet.
    transform=torchvision.transforms.ToTensor(),
)
# Out:
# ...
# 1.8%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 4.9%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 8.1%IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ...

# %%
print(type(train_data[0][0]))
print(type(train_data[0][1]))
# Out:
# <class 'torch.Tensor'>
# <class 'int'>

# %%
print(train_data[0][0].shape)
print(train_data[0][1])
# Out:
# torch.Size([3, 32, 32])
# 6

# %%
for index, (X, y) in enumerate(train_data):
    print(index)
    print(X.shape)  # torch.Tensor()
    print(y)  # int
    break
# Out:
# 0
# torch.Size([3, 32, 32])
# 6
