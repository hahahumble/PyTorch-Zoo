# %% [markdown]
# ### Custom Dataset Class (3)

# %% [markdown]
# When all images are stored together in a single folder, and filename indicates the class.</br>
# Structure like the following:
# ```
# Root
# ├── train.txt
# ├── val.txt
# ├── test.txt
# └── Images
#     ├── image01.jpg
#     ├── image02.jpg
#     ├── image03.jpg
#     ├── image04.jpg
#     └── ...
# ```

# %%
import glob
import numpy
from pathlib import Path

import torch
from torch.utils.data import Dataset, DataLoader
import torchvision

# %%
# Change this for your own directory.
ROOT_DIR = Path("/root/jupyter_projects")  # Your working directory.
DATASET_DIR = ROOT_DIR / "Data"  # Folder to store dataset.

DATA_DIR = DATASET_DIR / "Flowers102"

# %%
image_dir = DATA_DIR / "oxford-102-flowers"

train_label_path = DATA_DIR / "oxford-102-flowers/train.txt"
val_label_path = DATA_DIR / "oxford-102-flowers/valid.txt"
test_label_path = DATA_DIR / "oxford-102-flowers/test.txt"

# %%
path_list = []  # Store the path of images.
class_list = []  # Store the class name.

# %%
with open(train_label_path) as file:  # Get the content of label file.
    lines = file.readlines()

# %%
for line in lines:
    image_path, image_class = line.strip().split(' ')
    image_path = str(image_dir / image_path)  # Convert to string type.
    path_list.append(image_path)  # Store the path of images in list.
    class_list.append(int(image_class))

# %%
print(len(path_list))  # Total number of image in training set.
print(len(class_list))
# Out:
# 1020
# 1020

# %%
print(len(set(class_list)))  # 102 unique class.
# Out:
# 102

# %%
class Flowers102Dataset(Dataset):
    def __init__(self, image_paths, image_class, transform=None):
        self.image_paths = image_paths
        self.image_class = image_class
        self.transform = transform
        
    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        
        image_filepath = self.image_paths[idx]
        
        # For numpy array:
        # image = cv2.imread(image_filepath)
        # image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # For torch tensor:
        image = torchvision.io.read_image(image_filepath)
        
        label = self.image_class[idx]
        
        if self.transform is not None:
            image = self.transform(image=image)["image"]
        
        return image, label

# %%
Flowers102 = Flowers102Dataset(path_list, class_list)

# %%
for X, y in Flowers102:
    print(type(X))
    print(X.shape)  # (channel, width, height)
    
    print(type(y))
    print(y)
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 638, 500])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 656])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 601, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 542, 500])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 587, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 597])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 500, 621])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 500, 732])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 757])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 500, 718])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 600])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 731])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 536, 500])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 500, 715])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 648, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 581])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 684, 500])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 508, 500])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 561, 500])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 500, 603])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 504])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 635, 500])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 500, 551])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 500, 688])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 500, 541])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 532])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 513, 500])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 661])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 623])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 545, 500])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 730])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 714])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 508])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 614])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 618, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 505])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 500, 624])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 663])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 753])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 663])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 500, 703])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 530, 500])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 620])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 512, 500])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 500, 530])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 755])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 672])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 500, 635])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 524, 501])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 500, 598])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 501, 500])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 762])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 500, 539])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 506])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 760])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 500, 749])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 500, 552])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 745])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 544, 500])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 620, 500])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 699, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 500, 592])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 552])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 500, 670])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 706])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 566, 500])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 718])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 586])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 725, 500])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 702, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 807])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 824, 500])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 654, 500])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 678])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 500, 601])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 913, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 552, 500])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 500, 562])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 774, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 528])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 500, 519])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 648])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 673, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 592])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 597, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 554, 500])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 652])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 827])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 500, 789])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 560, 500])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 634])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 688, 500])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 739])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 500, 647])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 762])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 557, 500])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 624])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 528])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 544, 500])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 748])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 612, 500])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 500, 578])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 755, 500])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 702])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 517, 500])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 500, 521])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 596])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 693])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 625, 500])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 537])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 500, 692])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 500, 547])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 637])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 531])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 707, 500])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 687])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 501, 628])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 600])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 520, 500])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 569])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 528])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 657])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 800])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 504])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 766, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 501, 753])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 524])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 653])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 500, 687])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 701, 500])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 624, 500])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 662])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 665])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 508, 500])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 575])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 562, 500])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 500, 636])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 644])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 755])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 657])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 761])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 500, 531])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 775, 500])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 501, 762])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 696])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 500, 742])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 524, 500])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 555, 500])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 702])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 619, 500])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 626, 500])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 762, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 839])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 754])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 600])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 504])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 513, 500])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 652])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 799])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 500, 624])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 721])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 679])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 637])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 537])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 659])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 505, 500])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 636])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 500, 657])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 500, 799])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 501, 760])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 753, 501])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 500, 730])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 500, 777])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 648, 500])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 825])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 743])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 532, 500])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 500, 744])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 755])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 530, 500])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 700])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 731])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 500, 649])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 500, 535])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 771])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 604])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 500, 731])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 500, 741])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 535])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 532, 500])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 501, 753])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 546])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 708])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 554])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 502, 500])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 621])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 669, 500])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 553])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 665, 500])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 703, 500])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 503])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 582, 500])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 500, 780])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 500, 783])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 500, 679])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 500, 669])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 500, 673])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 754])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 527, 500])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 753, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 726, 500])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 658, 500])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 607, 500])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 659])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 731])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 861, 500])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 762, 500])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 751])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 686])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 500, 532])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 710])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 501, 738])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 714, 500])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 559, 500])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 631])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 751])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 780])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 662])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 795])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 736])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 500, 572])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 527, 500])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 707, 500])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 669, 500])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 500, 680])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 751, 500])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 696, 500])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 764, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 718])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 500, 633])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 654])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 764, 500])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 662])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 701])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 547, 500])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 538, 500])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 723])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 624, 500])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 766, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 500, 857])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 529, 500])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 627])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 845])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 642])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 791, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 749])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 627, 500])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 552, 500])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 570, 500])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 523, 500])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 512])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 717])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 632, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 660])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 500, 546])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 659])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 504, 501])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 751, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 542, 500])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 633])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 509, 500])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 694])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 632])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 566, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 500, 600])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 538, 500])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 518, 500])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 621])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 575, 500])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 727])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 500, 655])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 701])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 672])
# <class 'int'>
# 48
# <class 'torch.Tensor'>
# torch.Size([3, 500, 547])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 618])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 500, 679])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 759])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 747])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 535])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 516])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 542])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 629])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 551, 501])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 500, 535])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 518])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 551])
# <class 'int'>
# 75
# <class 'torch.Tensor'>
# torch.Size([3, 500, 693])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 647, 500])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 518, 500])
# <class 'int'>
# 97
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 536, 500])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 566])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 616])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 624])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 539, 500])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 527, 500])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 753, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 600])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 626, 500])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 954, 500])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 585])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 563])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 500, 740])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 751])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 697])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 500, 627])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 500, 647])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 587, 500])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 506])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 693])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 501, 550])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 549])
# <class 'int'>
# 95
# <class 'torch.Tensor'>
# torch.Size([3, 500, 546])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 500, 700])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 692])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 728, 500])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 625, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 528, 500])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 599])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 612, 500])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 516, 500])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 686, 500])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 627])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 685])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 637])
# <class 'int'>
# 53
# <class 'torch.Tensor'>
# torch.Size([3, 500, 806])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 681])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 588, 500])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 500, 690])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 609])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 500, 581])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 531, 500])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 804, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 600, 500])
# <class 'int'>
# 5
# <class 'torch.Tensor'>
# torch.Size([3, 500, 736])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 514, 500])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 539])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 781, 500])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 506])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 583, 500])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 674, 500])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 500, 751])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 926, 501])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 664])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 764, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 631, 500])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 501, 667])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 714, 500])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 538, 500])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 647])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 501, 519])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 993, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 580])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 519, 500])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 646])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 671, 500])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 679])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 626, 500])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 677, 500])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 500, 596])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 509, 500])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 558, 500])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 500, 747])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 751, 500])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 714])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 76
# <class 'torch.Tensor'>
# torch.Size([3, 652, 500])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 500, 558])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 625, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 731])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 630])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 705])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 500, 688])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 544, 500])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 715])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 515, 500])
# <class 'int'>
# 41
# <class 'torch.Tensor'>
# torch.Size([3, 531, 500])
# <class 'int'>
# 28
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 20
# <class 'torch.Tensor'>
# torch.Size([3, 604, 500])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 500, 570])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 549, 500])
# <class 'int'>
# 15
# <class 'torch.Tensor'>
# torch.Size([3, 735, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 502])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 500, 662])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 650, 500])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 682, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 736, 500])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 585])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 654])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 607, 500])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 570, 500])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 516, 500])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 509])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 721, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 707])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 68
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 550])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 679, 500])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 672])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 781])
# <class 'int'>
# 14
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 59
# ...
# torch.Size([3, 500, 701])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 545, 500])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 741])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 693, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 670, 500])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 501, 568])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 500, 665])
# <class 'int'>
# 47
# <class 'torch.Tensor'>
# torch.Size([3, 883, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 511, 500])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 751])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 500, 676])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 73
# <class 'torch.Tensor'>
# torch.Size([3, 500, 574])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 21
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 500, 660])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 760])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 611, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 500, 531])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 647, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 46
# <class 'torch.Tensor'>
# torch.Size([3, 500, 530])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 545, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 794, 500])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 652, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 505, 500])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 681])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 685])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 717])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 667, 501])
# <class 'int'>
# 43
# <class 'torch.Tensor'>
# torch.Size([3, 500, 919])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 500, 686])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 582])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 502, 500])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 564, 500])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 751, 500])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 772])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 529])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 625, 500])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 500, 596])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 680])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 500, 632])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 711, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 500, 618])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 501, 639])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 635, 500])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 506, 500])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 86
# <class 'torch.Tensor'>
# torch.Size([3, 500, 694])
# <class 'int'>
# 52
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 725, 500])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 607, 500])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 500, 692])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 500, 597])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 500, 537])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 71
# <class 'torch.Tensor'>
# torch.Size([3, 570, 500])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 500, 617])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 542])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 697])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 61
# <class 'torch.Tensor'>
# torch.Size([3, 658, 500])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 625, 500])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 500, 729])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 505, 500])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 559])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 737])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 500, 754])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 37
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 509, 500])
# <class 'int'>
# 67
# <class 'torch.Tensor'>
# torch.Size([3, 500, 542])
# <class 'int'>
# 25
# <class 'torch.Tensor'>
# torch.Size([3, 600, 500])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 49
# <class 'torch.Tensor'>
# torch.Size([3, 567, 500])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 92
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 58
# <class 'torch.Tensor'>
# torch.Size([3, 500, 749])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 752, 500])
# <class 'int'>
# 45
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 500, 684])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 500, 528])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 500, 682])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 562])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 33
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 635])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 626])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 930, 500])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 753, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 807, 500])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 676])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 90
# <class 'torch.Tensor'>
# torch.Size([3, 545, 501])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 590, 500])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 500, 672])
# <class 'int'>
# 4
# <class 'torch.Tensor'>
# torch.Size([3, 500, 723])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 627])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 508])
# <class 'int'>
# 12
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 749, 500])
# <class 'int'>
# 60
# <class 'torch.Tensor'>
# torch.Size([3, 500, 753])
# <class 'int'>
# 18
# <class 'torch.Tensor'>
# torch.Size([3, 625, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 500, 708])
# <class 'int'>
# 10
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 26
# <class 'torch.Tensor'>
# torch.Size([3, 575, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 500, 567])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 658])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 526, 501])
# <class 'int'>
# 70
# <class 'torch.Tensor'>
# torch.Size([3, 567, 500])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 825])
# <class 'int'>
# 72
# <class 'torch.Tensor'>
# torch.Size([3, 500, 790])
# <class 'int'>
# 69
# <class 'torch.Tensor'>
# torch.Size([3, 500, 556])
# <class 'int'>
# 30
# <class 'torch.Tensor'>
# torch.Size([3, 500, 754])
# <class 'int'>
# 0
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 593, 500])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 500, 845])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 617, 500])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 501, 762])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 505, 500])
# <class 'int'>
# 8
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])
# <class 'int'>
# 51
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 84
# <class 'torch.Tensor'>
# torch.Size([3, 500, 648])
# <class 'int'>
# 89
# <class 'torch.Tensor'>
# torch.Size([3, 676, 500])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 13
# <class 'torch.Tensor'>
# torch.Size([3, 500, 664])
# <class 'int'>
# 40
# <class 'torch.Tensor'>
# torch.Size([3, 500, 741])
# <class 'int'>
# 27
# <class 'torch.Tensor'>
# torch.Size([3, 650, 500])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 529])
# <class 'int'>
# 22
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 74
# <class 'torch.Tensor'>
# torch.Size([3, 500, 673])
# <class 'int'>
# 9
# <class 'torch.Tensor'>
# torch.Size([3, 500, 666])
# <class 'int'>
# 24
# <class 'torch.Tensor'>
# torch.Size([3, 592, 500])
# <class 'int'>
# 2
# <class 'torch.Tensor'>
# torch.Size([3, 500, 793])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 55
# <class 'torch.Tensor'>
# torch.Size([3, 500, 614])
# <class 'int'>
# 44
# <class 'torch.Tensor'>
# torch.Size([3, 729, 500])
# <class 'int'>
# 38
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 16
# <class 'torch.Tensor'>
# torch.Size([3, 607, 500])
# <class 'int'>
# 80
# <class 'torch.Tensor'>
# torch.Size([3, 500, 624])
# <class 'int'>
# 62
# <class 'torch.Tensor'>
# torch.Size([3, 577, 500])
# <class 'int'>
# 23
# <class 'torch.Tensor'>
# torch.Size([3, 500, 632])
# <class 'int'>
# 35
# <class 'torch.Tensor'>
# torch.Size([3, 541, 500])
# <class 'int'>
# 1
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 500, 502])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 87
# <class 'torch.Tensor'>
# torch.Size([3, 500, 683])
# <class 'int'>
# 64
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 88
# <class 'torch.Tensor'>
# torch.Size([3, 500, 542])
# <class 'int'>
# 78
# <class 'torch.Tensor'>
# torch.Size([3, 500, 609])
# <class 'int'>
# 100
# <class 'torch.Tensor'>
# torch.Size([3, 500, 701])
# <class 'int'>
# 6
# <class 'torch.Tensor'>
# torch.Size([3, 502, 500])
# <class 'int'>
# 19
# <class 'torch.Tensor'>
# torch.Size([3, 500, 751])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 660, 500])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 500, 694])
# <class 'int'>
# 82
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 83
# <class 'torch.Tensor'>
# torch.Size([3, 623, 500])
# <class 'int'>
# 36
# <class 'torch.Tensor'>
# torch.Size([3, 590, 501])
# <class 'int'>
# 96
# <class 'torch.Tensor'>
# torch.Size([3, 549, 500])
# <class 'int'>
# 31
# <class 'torch.Tensor'>
# torch.Size([3, 500, 645])
# <class 'int'>
# 56
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 99
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 598, 500])
# <class 'int'>
# 101
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 17
# <class 'torch.Tensor'>
# torch.Size([3, 500, 753])
# <class 'int'>
# 54
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 680])
# <class 'int'>
# 77
# <class 'torch.Tensor'>
# torch.Size([3, 500, 668])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 500, 755])
# <class 'int'>
# 34
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 32
# <class 'torch.Tensor'>
# torch.Size([3, 500, 669])
# <class 'int'>
# 85
# <class 'torch.Tensor'>
# torch.Size([3, 500, 757])
# <class 'int'>
# 3
# <class 'torch.Tensor'>
# torch.Size([3, 750, 500])
# <class 'int'>
# 65
# <class 'torch.Tensor'>
# torch.Size([3, 685, 500])
# <class 'int'>
# 39
# <class 'torch.Tensor'>
# torch.Size([3, 559, 500])
# <class 'int'>
# 91
# <class 'torch.Tensor'>
# torch.Size([3, 500, 625])
# <class 'int'>
# 29
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 79
# <class 'torch.Tensor'>
# torch.Size([3, 500, 769])
# <class 'int'>
# 50
# <class 'torch.Tensor'>
# torch.Size([3, 500, 667])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 696])
# <class 'int'>
# 98
# <class 'torch.Tensor'>
# torch.Size([3, 666, 500])
# <class 'int'>
# 42
# <class 'torch.Tensor'>
# torch.Size([3, 500, 568])
# <class 'int'>
# 11
# <class 'torch.Tensor'>
# torch.Size([3, 500, 750])
# <class 'int'>
# 63
# <class 'torch.Tensor'>
# torch.Size([3, 500, 549])
# <class 'int'>
# 66
# <class 'torch.Tensor'>
# torch.Size([3, 655, 500])
# <class 'int'>
# 7
# <class 'torch.Tensor'>
# torch.Size([3, 500, 661])
# <class 'int'>
# 94
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 59
# <class 'torch.Tensor'>
# torch.Size([3, 667, 500])
# <class 'int'>
# 93
# <class 'torch.Tensor'>
# torch.Size([3, 500, 752])
# <class 'int'>
# 57
# <class 'torch.Tensor'>
# torch.Size([3, 500, 660])
# <class 'int'>
# 81
# <class 'torch.Tensor'>
# torch.Size([3, 500, 523])
# <class 'int'>
# 10
